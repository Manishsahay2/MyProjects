# %%
# !pip install opendatasets

# %%
import numpy as nb

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"D:\Manish Folder\Data Analytics\Final assignment\Python.csv")

# %%
data.head(2)
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
#
#    Location Size   Color  Season  Review Rating Subscription Status  \
# 0  Kentucky    L    Gray  Winter            3.1                 Yes
# 1     Maine    L  Maroon  Winter            3.1                 Yes
#
#   Payment Method Shipping Type Discount Applied Promo Code Used  \
# 0    Credit Card       Express              Yes             Yes
# 1  Bank Transfer       Express              Yes             Yes
#
#    Previous Purchases Preferred Payment Method Frequency of Purchases
# 0                  14                    Venmo            Fortnightly
# 1                   2                     Cash            Fortnightly

# %% [markdown]
# This dataset provides detailed insights into retail sales, featuring a range of factors that influence sales performance. It includes records on sales revenue, units sold, discount percentages, marketing spend, and the impact of seasonal trends and holidays.

# %%
data.count()
# Out:
# Customer ID                 3900
# Age                         3900
# Gender                      3900
# Item Purchased              3900
# Category                    3900
# Purchase Amount (USD)       3900
# Location                    3900
# Size                        3900
# Color                       3900
# Season                      3900
# Review Rating               3900
# Subscription Status         3900
# Payment Method              3900
# Shipping Type               3900
# Discount Applied            3900
# Promo Code Used             3900
# Previous Purchases          3900
# Preferred Payment Method    3900
# Frequency of Purchases      3900
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3900 non-null   int64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3900 non-null   int64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3900 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %%
data.shape
# Out:
# (3900, 19)

# %%
data.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %%
data.head(5)
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
data['Item Purchased'].value_counts()
# Out:
# Item Purchased
# Blouse        171
# Jewelry       171
# Pants         171
# Shirt         169
# Dress         166
# Sweater       164
# Jacket        163
# Belt          161
# Sunglasses    161
# Coat          161
# Sandals       160
# Socks         159
# Skirt         158
# Shorts        157
# Scarf         157
# Hat           154
# Handbag       153
# Hoodie        151
# Shoes         150
# T-shirt       147
# Sneakers      145
# Boots         144
# Backpack      143
# Gloves        140
# Jeans         124
# Name: count, dtype: int64

# %%
data.head(3)
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
#
#         Location Size   Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L    Gray  Winter            3.1                 Yes
# 1          Maine    L  Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S  Maroon  Spring            3.1                 Yes
#
#   Payment Method  Shipping Type Discount Applied Promo Code Used  \
# 0    Credit Card        Express              Yes             Yes
# 1  Bank Transfer        Express              Yes             Yes
# 2           Cash  Free Shipping              Yes             Yes
#
#    Previous Purchases Preferred Payment Method Frequency of Purchases
# ...

# %%
data[data['Location'].isin(['Maine','Virginia'])]
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 1               2   19    Male        Sweater     Clothing
# 71             72   36    Male          Dress     Clothing
# 81             82   67    Male          Shoes     Footwear
# 97             98   21    Male          Shoes     Footwear
# 116           117   55    Male          Shoes     Footwear
# ...           ...  ...     ...            ...          ...
# 3784         3785   54  Female          Socks     Clothing
# 3815         3816   32  Female            Hat  Accessories
# 3856         3857   39  Female        Sandals     Footwear
# 3888         3889   45  Female       Sneakers     Footwear
# 3895         3896   40  Female         Hoodie     Clothing
#
#       Purchase Amount (USD)  Location Size      Color  Season  Review Rating  \
# 1                        64     Maine    L     Maroon  Winter            3.1
# 71                       48  Virginia    L       Gold  Summer            2.9
# ...

# %%
data.head(5)
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
data[~(data['Item Purchased'] == 'Blouse')]
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 5               6   46    Male       Sneakers     Footwear
# 6               7   63    Male          Shirt     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 1                        64          Maine    L     Maroon  Winter
# 2                        73  Massachusetts    S     Maroon  Spring
# ...

# %%
data['Purchase Amount (USD)'] = data['Purchase Amount (USD)'].apply(lambda x:x+5)

# %%
data.head(5)
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
data.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     58
# 1            2   19   Male        Sweater  Clothing                     69
# 2            3   50   Male          Jeans  Clothing                     78
# 3            4   21   Male        Sandals  Footwear                     95
# 4            5   45   Male         Blouse  Clothing                     54
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
data.head().sum()
# Out:
# Customer ID                                                                15
# Age                                                                       190
# Gender                                                   MaleMaleMaleMaleMale
# Item Purchased                                BlouseSweaterJeansSandalsBlouse
# Category                             ClothingClothingClothingFootwearClothing
# Purchase Amount (USD)                                                     354
# Location                         KentuckyMaineMassachusettsRhode IslandOregon
# Size                                                                    LLSMM
# Color                                         GrayMaroonMaroonMaroonTurquoise
# Season                                         WinterWinterSpringSpringSpring
# Review Rating                                                            15.5
# Subscription Status                                           YesYesYesYesYes
# ...

# %%
data.shape
# Out:
# (3900, 19)

# %%
data.isnull()
# Out:
#       Customer ID    Age  Gender  Item Purchased  Category  \
# 0           False  False   False           False     False
# 1           False  False   False           False     False
# 2           False  False   False           False     False
# 3           False  False   False           False     False
# 4           False  False   False           False     False
# ...           ...    ...     ...             ...       ...
# 3895        False  False   False           False     False
# 3896        False  False   False           False     False
# 3897        False  False   False           False     False
# 3898        False  False   False           False     False
# 3899        False  False   False           False     False
#
#       Purchase Amount (USD)  Location   Size  Color  Season  Review Rating  \
# 0                     False     False  False  False   False          False
# 1                     False     False  False  False   False          False
# ...

# %%
data.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %% [markdown]
# This dataset provides detailed insights into retail sales, featuring a range of factors that influence sales performance. It includes records on sales revenue, units sold, discount percentages, marketing spend, and the impact of seasonal trends and holidays.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3900 non-null   int64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3900 non-null   int64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3900 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %%
print('Missing Values:'.upper())
# Out:
# MISSING VALUES:

# %%
data.isna().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %%
print(data.isna().sum())
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %%
(f'There is {data.duplicated().sum()} duplicates')
# Out:
# 'There is 0 duplicates'

# %%
data.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              64.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              25.000000       2.500000
# 25%     975.750000    31.000000              44.000000       3.100000
# 50%    1950.500000    44.000000              65.000000       3.700000
# 75%    2925.250000    57.000000              86.000000       4.400000
# max    3900.000000    70.000000             105.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %% [markdown]
# Number of Customers based on Age

# %%
data.head(2)
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     58
# 1            2   19   Male        Sweater  Clothing                     69
#
#    Location Size   Color  Season  Review Rating Subscription Status  \
# 0  Kentucky    L    Gray  Winter            3.1                 Yes
# 1     Maine    L  Maroon  Winter            3.1                 Yes
#
#   Payment Method Shipping Type Discount Applied Promo Code Used  \
# 0    Credit Card       Express              Yes             Yes
# 1  Bank Transfer       Express              Yes             Yes
#
#    Previous Purchases Preferred Payment Method Frequency of Purchases
# 0                  14                    Venmo            Fortnightly
# 1                   2                     Cash            Fortnightly

# %%
data['Age group'] = data['Age'].apply(lambda x: 'Young' if x<=30 else ('senior' if x>=51 else 'Middle aged'))

# %%
data.head(2)
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     58
# 1            2   19   Male        Sweater  Clothing                     69
#
#    Location Size   Color  Season  Review Rating Subscription Status  \
# 0  Kentucky    L    Gray  Winter            3.1                 Yes
# 1     Maine    L  Maroon  Winter            3.1                 Yes
#
#   Payment Method Shipping Type Discount Applied Promo Code Used  \
# 0    Credit Card       Express              Yes             Yes
# 1  Bank Transfer       Express              Yes             Yes
#
#    Previous Purchases Preferred Payment Method Frequency of Purchases  \
# 0                  14                    Venmo            Fortnightly
# 1                   2                     Cash            Fortnightly
#
#   Age group
# 0    senior
# 1     Young

# %%
byage = data.groupby('Age group').agg({'Customer ID': 'nunique'}).rename(columns={'Customer ID': 'Customer Count'})

byage
# Out:
#              Customer Count
# Age group
# Middle aged            1475
# Young                   949
# senior                 1476

# %%
data.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     58
# 1            2   19   Male        Sweater  Clothing                     69
# 2            3   50   Male          Jeans  Clothing                     78
# 3            4   21   Male        Sandals  Footwear                     95
# 4            5   45   Male         Blouse  Clothing                     54
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %% [markdown]
# The number of customers based on gender

# %%
bygender = data.groupby('Gender').agg({'Customer ID': 'nunique'}).rename(columns={'Customer ID': 'Customer Count'})

bygender
# Out:
#         Customer Count
# Gender
# Female            1248
# Male              2652

# %% [markdown]
# The number of customers based on item purchased and category.

# %%
bycategory = data.groupby('Category').agg({'Customer ID': 'nunique'}).rename(columns={'Customer ID': 'Customer Count'})

bycategory
# Out:
#              Customer Count
# Category
# Accessories            1240
# Clothing               1737
# Footwear                599
# Outerwear               324

# %%
byitems = data.groupby(['Category', 'Item Purchased']).agg({'Customer ID': 'nunique'}).rename(columns={'Customer ID': 'Customer Count'})

byitems
# Out:
#                             Customer Count
# Category    Item Purchased
# Accessories Backpack                   143
#             Belt                       161
#             Gloves                     140
#             Handbag                    153
#             Hat                        154
#             Jewelry                    171
#             Scarf                      157
#             Sunglasses                 161
# Clothing    Blouse                     171
#             Dress                      166
#             Hoodie                     151
#             Jeans                      124
#             Pants                      171
#             Shirt                      169
#             Shorts                     157
#             Skirt                      158
#             Socks                      159
#             Sweater                    164
#             T-shirt                    147
# Footwear    Boots                      144
# ...

# %% [markdown]
# Customer preferences regarding products

# %%
product_size = data.groupby('Size').agg({'Customer ID': 'nunique'}).rename(columns={'Customer ID': 'Customer Count'})

product_size
# Out:
#       Customer Count
# Size
# L               1053
# M               1755
# S                663
# XL               429

# %% [markdown]
# The number of customers based on purchase amount.

# %%
Customers = data.groupby('Purchase Amount (USD)').agg({'Customer ID': 'nunique'}).rename(columns={'Customer ID': 'Customer Count'})

Customers.sort_index(ascending=False).head()
# Out:
#                        Customer Count
# Purchase Amount (USD)
# 105                                36
# 104                                52
# 103                                52
# 102                                55
# 101                                53

# %% [markdown]
# The number of customers based on location.

# %%
Location = data.groupby('Location').agg({'Customer ID': 'nunique'}).rename(columns={'Customer ID': 'Customer Count'})

Location.sort_values('Customer Count', ascending=False).head(5)
# Out:
#             Customer Count
# Location
# Montana                 96
# California              95
# Idaho                   93
# Illinois                92
# Alabama                 89

# %% [markdown]
# The number of customers based on review rating.
#
# Below 3.5 - Bad
# 3.5 - 3.9 - Good
# Above 4.0  - Very Good

# %%
data['Rating Group'] = data['Review Rating'].apply(lambda x: 'Bad' if x < 3.5 else('Very Good' if x >= 4 else 'Good'))

# %%
byrating = data.groupby('Rating Group').agg({'Customer ID': 'nunique'}).rename(columns={'Customer ID': 'Customer Count'})

byrating
# Out:
#               Customer Count
# Rating Group
# Bad                     1490
# Good                     766
# Very Good               1644

# %% [markdown]
# The number of customers based on subscription status.

# %%
data.head(2)
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     58
# 1            2   19   Male        Sweater  Clothing                     69
#
#    Location Size   Color  Season  ...  Subscription Status Payment Method  \
# 0  Kentucky    L    Gray  Winter  ...                  Yes    Credit Card
# 1     Maine    L  Maroon  Winter  ...                  Yes  Bank Transfer
#
#   Shipping Type Discount Applied Promo Code Used Previous Purchases  \
# 0       Express              Yes             Yes                 14
# 1       Express              Yes             Yes                  2
#
#    Preferred Payment Method Frequency of Purchases Age group Rating Group
# 0                     Venmo            Fortnightly    senior          Bad
# 1                      Cash            Fortnightly     Young          Bad
#
# [2 rows x 21 columns]

# %%
Subscriptiom = data.groupby('Subscription Status').agg({'Customer ID': 'nunique'}).rename(columns={'Customer ID': 'Customer Count'})

Subscriptiom
# Out:
#                      Customer Count
# Subscription Status
# No                             2847
# Yes                            1053

# %%
Subscriptiom = data.groupby(['Discount Applied', 'Promo Code Used']).agg({'Customer ID': 'nunique'}).rename(columns={'Customer ID': 'Customer Count'})

Subscriptiom
# Out:
#                                   Customer Count
# Discount Applied Promo Code Used
# No               No                         2223
# Yes              Yes                        1677

# %% [markdown]
# The number of customers based on payment method.

# %%
Payment = data.groupby('Payment Method').agg({'Customer ID': 'nunique'}).rename(columns={'Customer ID': 'Customer Count'})

Payment
# Out:
#                 Customer Count
# Payment Method
# Bank Transfer              632
# Cash                       648
# Credit Card                696
# Debit Card                 633
# PayPal                     638
# Venmo                      653

# %% [markdown]
# The number of customers based on frequency of purchases.

# %%
frequency = data.groupby('Frequency of Purchases').agg({'Customer ID': 'nunique'}).rename(columns={'Customer ID': 'Customer Count'})

frequency
# Out:
#                         Customer Count
# Frequency of Purchases
# Annually                           572
# Bi-Weekly                          547
# Every 3 Months                     584
# Fortnightly                        542
# Monthly                            553
# Quarterly                          563
# Weekly                             539

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(15,5))

sns.barplot(
    data=byage.sort_values(by='Customer Count', ascending=False).reset_index(),
    x='Age group',
    y='Customer Count',
    ax=ax[0]
)
ax[0].set_title('By Age group')

sns.barplot(
    data=bygender.sort_values(by='Customer Count', ascending=False).reset_index(),
    x='Gender',
    y='Customer Count',
    ax=ax[1]
)
ax[1].set_title('By Gender')

sns.barplot(
    data=Location.reset_index().sort_values(by='Customer Count', ascending=False).head(),
    x='Location',
    y='Customer Count',
    ax=ax[2]
)
ax[2].set_title('By Location')

for i in range(3):
  ax[i].set_xlabel(None)
  ax[i].set_ylabel(None)

# %%
product_color = data.groupby('Color').agg({'Customer ID': 'nunique'}).rename(columns={'Customer ID': 'Customer Count'})

product_color.sort_values(by='Customer Count', ascending=False).head()
# Out:
#         Customer Count
# Color
# Olive              177
# Yellow             174
# Silver             173
# Teal               172
# Green              169

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(15,5))
colors = ['#72BCD4', '#C4E9F5', '#C4E9F5', '#C4E9F5', '#C4E9F5', '#C4E9F5', '#C4E9F5', '#C4E9F5', '#C4E9F5', '#C4E9F5']

sns.barplot(
    data=product_size.reset_index().sort_values(by='Customer Count', ascending=False),
    x='Size',
    y='Customer Count',
    ax=ax[0]
)
ax[0].set_title('Product Preferences by Size')

sns.barplot(
    data=product_color.reset_index().sort_values(by='Customer Count', ascending=False).head(7),
    x='Color',
    y='Customer Count',

    ax=ax[1]
)
ax[1].set_title('Product Preferences by Color')

sns.barplot(
    data=byrating.reset_index().sort_values(by='Customer Count', ascending=False),
    x='Rating Group',
    y='Customer Count',

    ax=ax[2]
)
ax[2].set_title('Product Preferences by Rating')

for i in range(3):
  ax[i].set_xlabel(None)
  ax[i].set_ylabel(None)

# %% [markdown]
# Based on size and color, the most sold products are size M and olive-colored.

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(15,5))

sns.barplot(
    data=bycategory.sort_values(by='Customer Count', ascending=False).reset_index(),
    x='Category',
    y='Customer Count',
    errorbar=None,
    ax=ax[0]
)
ax[0].set_title('Product Category')

sns.barplot(
    data=byitems.sort_values(by='Customer Count', ascending=False).reset_index().head(),
    x='Item Purchased',
    y='Customer Count',
    ax=ax[1]
)
ax[1].set_title('Best-selling Items')

sns.barplot(
    data=byitems.sort_values(by='Customer Count', ascending=True).reset_index().head(),
    x='Item Purchased',
    y='Customer Count',
    ax=ax[2]
)
ax[2].set_title('Least-selling Items')

for i in range(3):
  ax[i].set_xlabel(None)
  ax[i].set_ylabel(None)

# %% [markdown]
# The most favored product category is clothing, with the best-selling item is pants, while the least-selling item is jeans. However, it should be noted that the difference between these two items is not too significant

# %% [markdown]
# Is there a specific pattern in customer purchasing behavior during certain seasons?

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=byseason.reset_index().sort_values(by='Customer Count', ascending=False),
    x='Season',
    y='Customer Count',
)
plt.title('Customer Count by Season')
plt.xlabel(None)
plt.ylabel(None)

plt.show()

# %% [markdown]
# The number of customers based on season.

# %% [markdown]
# From the graph, it can be observed that there is no significant difference between seasons, showing no specific pattern in customer purchasing behavior.

# %% [markdown]
# How is customer purchasing behavior influenced by discounts and the use of promo codes?

# %%
plt.figure(figsize=(8,5))

plt.pie(
    data=bydisc_promo.reset_index(),
    x='Customer Count',
    labels='Discount Applied',
    autopct="%.1f%%",
    colors=colors,
    wedgeprops={'width': 0.4},
    labeldistance=1.2,
    pctdistance=1.1
)

plt.title('By Discounts and Promo Codes', pad=20)
plt.show()

# %% [markdown]
# More customers do not use discounts and promo codes when making purchases, showing that discounts and promotions do not significantly influence customer purchasing behavior.

# %% [markdown]
# What percentage of customers subscribe to products or services when making a purchase?

# %%
plt.figure(figsize=(8,5))
colors = ['#72BCD4', '#D47DA4']

plt.pie(
    data=bysubs.reset_index(),
    x='Customer Count',
    labels='Subscription Status',
    autopct="%.1f%%",
    colors=colors,
    wedgeprops={'width': 0.4},
    labeldistance=1.3,
    pctdistance=1.15
)

plt.title('By Subscription Status')
plt.show()

# %% [markdown]
# Out of the total customers, about 27% subscribe when making a purchase, which means the majority do not subscribe.
